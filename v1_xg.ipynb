# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings(action='ignore')

# %%
import os

path = "./table_v1"
dir_list = os.listdir(path)
dir_list
# Out:
# ['table_202001_v1.csv',
#  'table_202002_v1.csv',
#  'table_202003_v1.csv',
#  'table_202004_v1.csv',
#  'table_202005_v1.csv',
#  'table_202006_v1.csv',
#  'table_202007_v1.csv',
#  'table_202008_v1.csv',
#  'table_202009_v1.csv',
#  'table_202010_v1.csv',
#  'table_202011_v1.csv',
#  'table_202012_v1.csv',
#  'table_202101_v1.csv',
#  'table_202102_v1.csv',
#  'table_202103_v1.csv',
#  'table_202104_v1.csv',
#  'table_202105_v1.csv',
#  'table_202106_v1.csv',
#  'table_202107_1_v1.csv',
#  'table_202107_2_v1.csv',
#  'table_202108_1_v1.csv',
#  'table_202108_2_v1.csv',
#  'table_202109_v1.csv',
#  'table_202110_v1.csv',
#  'table_202111_v1.csv',
#  'table_202112_v1.csv']

# %%
dir_train = dir_list

# %%
dir_train.remove('table_202107_1_v1.csv')
dir_train.remove('table_202108_2_v1.csv')
dir_train.remove('table_202109_v1.csv')
dir_train.remove('table_202110_v1.csv')
dir_train.remove('table_202111_v1.csv')
dir_train.remove('table_202112_v1.csv')

dir_train
# Out:
# ['table_202001_v1.csv',
#  'table_202002_v1.csv',
#  'table_202003_v1.csv',
#  'table_202004_v1.csv',
#  'table_202005_v1.csv',
#  'table_202006_v1.csv',
#  'table_202007_v1.csv',
#  'table_202008_v1.csv',
#  'table_202009_v1.csv',
#  'table_202010_v1.csv',
#  'table_202011_v1.csv',
#  'table_202012_v1.csv',
#  'table_202101_v1.csv',
#  'table_202102_v1.csv',
#  'table_202103_v1.csv',
#  'table_202104_v1.csv',
#  'table_202105_v1.csv',
#  'table_202106_v1.csv',
#  'table_202107_2_v1.csv',
#  'table_202108_1_v1.csv']

# %%
train = pd.DataFrame()
for files in dir_train:
    df = pd.read_csv('./table_v1/'+files)
    train = pd.concat([train,df])
    
train
# Out:
#         YearMonthDayHourMinute  STN        Lon       Lat  isitu-LST    Band1  \
# 0                 202001010000   90  128.56473  38.25085       -2.6  0.00000
# 1                 202001010000   95  127.30420  38.14787       -2.6 -0.00057
# 2                 202001010000   98  127.06070  37.90188       -3.1  0.00000
# 3                 202001010000   99  126.76648  37.88589       -3.4 -0.00057
# 4                 202001010000  101  127.73570  37.90262       -3.6 -0.00057
# ...                        ...  ...        ...       ...        ...      ...
# 296417            202108202350  973  126.94961  35.02330       24.5 -0.00057
# 296418            202108202350  974  128.15605  35.24435       22.6  0.00000
# 296419            202108202350  977  127.46688  36.72455       24.5  0.00057
# 296420            202108202350  978  127.77626  37.95461       23.5  0.00000
# 296421            202108202350  980  126.48951  33.26062       27.2  0.00000
#
#           Band2   Band3    Band4   Band5  ...  insitu-TED0.1  insitu-TED0.2  \
# 0       0.00000 -0.0006 -0.00030 -0.0003  ...         -999.0         -999.0
# 1      -0.00057  0.0003 -0.00060 -0.0003  ...         -999.0         -999.0
# 2       0.00000  0.0003  0.00060 -0.0003  ...         -999.0         -999.0
# 3      -0.00057 -0.0003  0.00015  0.0000  ...         -999.0         -999.0
# 4       0.00000  0.0003  0.00030  0.0000  ...           -0.6            0.7
# ...         ...     ...      ...     ...  ...            ...            ...
# 296417  0.00000  0.0000  0.00135  0.0006  ...           27.8           27.3
# 296418  0.00000  0.0000  0.00120  0.0006  ...           26.9           27.2
# 296419  0.00057  0.0006 -0.00015  0.0000  ...           27.6           27.8
# 296420  0.00000  0.0003 -0.00015  0.0003  ...           28.3           28.1
# 296421 -0.00057  0.0000  0.00015  0.0003  ...           28.0           27.7
#
#         insitu-TED0.3  insitu-TED0.5  insitu-TED1.0  insitu-TED1.5  \
# 0              -999.0         -999.0         -999.0         -999.0
# 1              -999.0         -999.0         -999.0         -999.0
# 2              -999.0         -999.0         -999.0         -999.0
# 3              -999.0         -999.0         -999.0         -999.0
# 4                 1.5            3.1            6.9           10.2
# ...               ...            ...            ...            ...
# 296417           27.6           26.8           25.5         -999.0
# 296418           27.6           26.8           17.6         -999.0
# 296419           27.5           27.1           25.8         -999.0
# 296420           27.5           26.7           25.1         -999.0
# 296421           26.3           26.5           25.5         -999.0
#
#         insitu-TED3.0  insitu-TED5.0  insitu-PA  insitu-PS
# 0              -999.0         -999.0     1025.2     1027.5
# 1              -999.0         -999.0     1014.1     1034.6
# 2              -999.0         -999.0     1019.6     1034.8
# 3              -999.0         -999.0     1030.6     1034.6
# 4                15.1           16.9     1024.0     1034.1
# ...               ...            ...        ...        ...
# 296417         -999.0         -999.0     1006.3     1010.8
# 296418         -999.0         -999.0     -999.0     -999.0
# 296419         -999.0         -999.0     -999.0     -999.0
# 296420         -999.0         -999.0     -999.0     -999.0
# 296421         -999.0         -999.0     -999.0     -999.0
#
# [8797313 rows x 44 columns]

# %%
dir_val = ['table_202109_v1.csv','table_202110_v1.csv','table_202111_v1.csv','table_202112_v1.csv']
val = pd.DataFrame()
for files in dir_val:
    df = pd.read_csv('./table_v1/'+files)
    val = pd.concat([val,df])
    
val
# Out:
#         YearMonthDayHourMinute  STN        Lon       Lat  isitu-LST    Band1  \
# 0                 202109010000   90  128.56473  38.25085       17.9  0.00170
# 1                 202109010000   93  127.75443  37.94738       19.0  0.00170
# 2                 202109010000   95  127.30420  38.14787       17.6  0.00170
# 3                 202109010000   98  127.06070  37.90188       19.3  0.00227
# 4                 202109010000   99  126.76648  37.88589       19.6  0.00227
# ...                        ...  ...        ...       ...        ...      ...
# 432625            202112312350  702  126.99435  35.94504       -3.2 -0.00057
# 432626            202112312350  972  128.68340  36.54983       -4.8 -0.00057
# 432627            202112312350  973  126.94961  35.02330       -2.4  0.00000
# 432628            202112312350  974  128.15605  35.24435       -1.8 -0.00057
# 432629            202112312350  980  126.48951  33.26062        4.5 -0.00057
#
#           Band2    Band3    Band4    Band5  ...  insitu-TED0.1  insitu-TED0.2  \
# 0       0.00171  0.00238  0.00195  0.00181  ...         -999.0         -999.0
# 1       0.00171  0.00149  0.00180  0.00121  ...           21.1           22.5
# 2       0.00228  0.00179  0.00195  0.00151  ...         -999.0         -999.0
# 3       0.00228  0.00238  0.00374  0.00181  ...         -999.0         -999.0
# 4       0.00228  0.00268  0.00239  0.00151  ...         -999.0         -999.0
# ...         ...      ...      ...      ...  ...            ...            ...
# 432625 -0.00057 -0.00030 -0.00045 -0.00030  ...            0.6            1.3
# 432626  0.00057  0.00089 -0.00015  0.00000  ...            0.1            1.4
# 432627 -0.00057 -0.00179  0.00015 -0.00030  ...            2.0            2.9
# 432628 -0.00057  0.00060 -0.00015  0.00000  ...            0.8            0.4
# 432629 -0.00057 -0.00268 -0.00090  0.00000  ...            7.0            7.2
#
#         insitu-TED0.3  insitu-TED0.5  insitu-TED1.0  insitu-TED1.5  \
# 0              -999.0         -999.0         -999.0         -999.0
# 1                23.5           24.3           24.6           23.8
# 2              -999.0         -999.0         -999.0         -999.0
# 3              -999.0         -999.0         -999.0         -999.0
# 4              -999.0         -999.0         -999.0         -999.0
# ...               ...            ...            ...            ...
# 432625            2.6            3.6            6.2         -999.0
# 432626            2.1            2.5            5.3         -999.0
# 432627            4.0            5.6            8.7         -999.0
# 432628            3.4            4.6            9.4         -999.0
# 432629            7.1           10.8           14.8         -999.0
#
#         insitu-TED3.0  insitu-TED5.0  insitu-PA  insitu-PS
# 0              -999.0         -999.0     1012.7     1014.8
# 1                21.2           17.7     1001.1     1012.3
# 2              -999.0         -999.0      994.6     1012.7
# 3              -999.0         -999.0      998.6     1012.1
# 4              -999.0         -999.0     1008.2     1011.8
# ...               ...            ...        ...        ...
# 432625         -999.0         -999.0     -999.0     -999.0
# 432626         -999.0         -999.0     1021.2     1032.8
# 432627         -999.0         -999.0     1028.5     1033.7
# 432628         -999.0         -999.0     -999.0     -999.0
# 432629         -999.0         -999.0     -999.0     -999.0
#
# [1780159 rows x 44 columns]

# %%
dir_test = ['table_202107_1_v1.csv','table_202108_2_v1.csv']
test = pd.DataFrame()
for files in dir_test:
    df = pd.read_csv('./table_v1/'+files)
    test = pd.concat([test,df])
    
test
# Out:
#        YearMonthDayHourMinute  STN        Lon       Lat    Band1    Band2  \
# 0                202107000000   90  128.56473  38.25085 -0.00057 -0.00057
# 1                202107000000   93  127.75443  37.94738 -0.00057 -0.00057
# 2                202107000000   95  127.30420  38.14787 -0.00057 -0.00057
# 3                202107000000   98  127.06070  37.90188 -0.00057 -0.00057
# 4                202107000000   99  126.76648  37.88589 -0.00057  0.00000
# ...                       ...  ...        ...       ...      ...      ...
# 27087            202108000000  973  126.94961  35.02330  0.00000  0.00000
# 27088            202108000000  974  128.15605  35.24435  0.00000  0.00057
# 27089            202108000000  977  127.46688  36.72455  0.00000  0.00057
# 27090            202108000000  978  127.77626  37.95461  0.00000  0.00000
# 27091            202108000000  980  126.48951  33.26062  0.00000  0.00000
#
#          Band3    Band4    Band5    Band6  ...  insitu-TED0.1  insitu-TED0.2  \
# 0     -0.00149 -0.00045 -0.00060  0.00000  ...         -999.0         -999.0
# 1     -0.00119  0.00000  0.00000 -0.00065  ...           24.3           25.6
# 2     -0.00060  0.00015  0.00000 -0.00065  ...         -999.0         -999.0
# 3      0.00030 -0.00015 -0.00030 -0.00065  ...         -999.0         -999.0
# 4     -0.00060 -0.00105  0.00000 -0.00065  ...         -999.0         -999.0
# ...        ...      ...      ...      ...  ...            ...            ...
# 27087  0.00030  0.00015  0.00121  0.00000  ...           28.3           27.7
# 27088  0.00000  0.00015  0.00000  0.00000  ...           28.6           28.7
# 27089 -0.00179  0.00030  0.00000  0.00000  ...           24.2           24.5
# 27090  0.00089  0.00015 -0.00030  0.00000  ...           22.8           23.8
# 27091  0.00030 -0.00015  0.00000  0.00000  ...           29.8           29.1
#
#        insitu-TED0.3  insitu-TED0.5  insitu-TED1.0  insitu-TED1.5  \
# 0             -999.0         -999.0         -999.0         -999.0
# 1               25.6           24.6           21.9           19.5
# 2             -999.0         -999.0         -999.0         -999.0
# 3             -999.0         -999.0         -999.0         -999.0
# 4             -999.0         -999.0         -999.0         -999.0
# ...              ...            ...            ...            ...
# 27087           27.8           26.8           25.1         -999.0
# 27088           28.8           27.9           25.6         -999.0
# 27089           24.7           24.7           24.4         -999.0
# 27090           24.3           24.2           24.1         -999.0
# 27091           27.5           27.5           25.8         -999.0
#
#        insitu-TED3.0  insitu-TED5.0  insitu-PA  insitu-PS
# 0             -999.0         -999.0     1006.2     1008.2
# 1               15.3           13.5      996.8     1007.8
# 2             -999.0         -999.0      990.4     1008.2
# 3             -999.0         -999.0      994.8     1008.1
# 4             -999.0         -999.0     1004.6     1008.2
# ...              ...            ...        ...        ...
# 27087         -999.0         -999.0     1008.8     1013.3
# 27088         -999.0         -999.0     -999.0     -999.0
# 27089         -999.0         -999.0     -999.0     -999.0
# 27090         -999.0         -999.0     -999.0     -999.0
# 27091         -999.0         -999.0     -999.0     -999.0
#
# [54503 rows x 42 columns]

# %%
train.columns
# Out:
# Index(['YearMonthDayHourMinute', 'STN', 'Lon', 'Lat', 'isitu-LST', 'Band1',
#        'Band2', 'Band3', 'Band4', 'Band5', 'Band6', 'Band7', 'Band8', 'Band9',
#        'Band10', 'Band11', 'Band12', 'Band13', 'Band14', 'Band15', 'Band16',
#        '30daysBand3', '30daysBand13', 'GK2A-LST', 'SolarZA', 'SateZA', 'ESR',
#        'Height', 'LandType', 'insitu-TA', 'insitu-HM', 'insitu-TD',
#        'insitu-TG', 'insitu-TED0.05', 'insitu-TED0.1', 'insitu-TED0.2',
#        'insitu-TED0.3', 'insitu-TED0.5', 'insitu-TED1.0', 'insitu-TED1.5',
#        'insitu-TED3.0', 'insitu-TED5.0', 'insitu-PA', 'insitu-PS'],
#       dtype='object')

# %%
X_train = train.drop(['Band2','Band3','Band4','Band5','Band6','Band7','Band8','Band9','Band10','Band11','Band12',
            'Band13','Band14','Band15','Band16','30daysBand3','30daysBand13','GK2A-LST', 
           'insitu-TED0.2','insitu-TED0.3','insitu-TED0.5','insitu-TED1.0','insitu-TED1.5','insitu-TED3.0', 
           'insitu-TED5.0','insitu-PA','insitu-PS','YearMonthDayHourMinute', 
           'STN','Lon','Lat','isitu-LST','insitu-TA'], axis=1)
X_test = val.drop(['Band2','Band3','Band4','Band5','Band6','Band7','Band8','Band9','Band10','Band11','Band12', \
            'Band13','Band14','Band15','Band16','30daysBand3','30daysBand13','GK2A-LST', \
           'insitu-TED0.2','insitu-TED0.3','insitu-TED0.5','insitu-TED1.0','insitu-TED1.5','insitu-TED3.0', \
           'insitu-TED5.0','insitu-PA','insitu-PS','YearMonthDayHourMinute', \
           'STN','Lon','Lat','isitu-LST','insitu-TA'], axis=1)

y_train=train[['isitu-LST', 'insitu-TA']].values
y_test=val[['isitu-LST', 'insitu-TA']].values

X_train
# Out:
#           Band1    SolarZA    SateZA      ESR  Height  LandType  insitu-HM  \
# 0       0.00000  162.63634  44.52481 -9.38141   17.53         2       30.3
# 1      -0.00057  162.17793  44.41427 -9.36082  155.48         2       64.1
# 2       0.00000  162.27711  44.13104 -9.36664  115.62         2       58.4
# 3      -0.00057  162.14729  44.12316 -9.36060   30.59         2       52.8
# 4      -0.00057  162.57755  44.12761 -9.38050   75.82         3       66.0
# ...         ...        ...       ...      ...     ...       ...        ...
# 296417 -0.00057  130.99817  40.87855 -5.63009   39.64         2       81.7
# 296418  0.00000  131.08437  41.10588 -5.67084   16.78         2       94.4
# 296419  0.00057  129.50209  42.79873 -5.46819   40.35         2       98.3
# 296420  0.00000  128.39204  44.18884 -5.34326  140.37         2       85.2
# 296421  0.00000  132.53889  38.90221 -5.79447  141.84         2       89.9
#
#         insitu-TD  insitu-TG  insitu-TED0.05  insitu-TED0.1
# 0           -17.7       -4.2          -999.0         -999.0
# 1           -14.5       -7.9          -999.0         -999.0
# 2           -14.7       -7.4          -999.0         -999.0
# 3           -15.4       -6.5          -999.0         -999.0
# 4           -14.3      -14.1            -0.5           -0.6
# ...           ...        ...             ...            ...
# 296417       22.6       24.7            27.8           27.8
# 296418       20.7     -999.0            26.2           26.9
# 296419       23.1       25.7            28.0           27.6
# 296420       19.4       20.5            27.5           28.3
# 296421       24.1       26.7            27.5           28.0
#
# [8797313 rows x 11 columns]

# %%
pip install xgboost
# Out:
# Collecting xgboost
#   Downloading xgboost-1.6.1-py3-none-win_amd64.whl (125.4 MB)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\envs\tf_gpu\lib\site-packages (from xgboost) (1.21.5)
# Requirement already satisfied: scipy in c:\programdata\anaconda3\envs\tf_gpu\lib\site-packages (from xgboost) (1.7.3)
# Installing collected packages: xgboost
# Successfully installed xgboost-1.6.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import xgboost as xgb
# xg_reg = xgb.XGBRegressor(objective ='reg:linear', colsample_bytree = 0.3, learning_rate = 0.1, max_depth = 5, alpha = 10, n_estimators = 10)
# xg_reg.fit(X_train,y_train)

xgb_model = xgb.XGBRegressor(n_estimators = 200, learning_rate = 0.1, random_state = 2000).fit(X_train,y_train, eval_set=[(X_test, y_test)], verbose=False)

# %%
xgb_model
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.1, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#              missing=nan, monotone_constraints='()', n_estimators=200, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=2000,
#              reg_alpha=0, reg_lambda=1, ...)

# %%
filename = 'xgb_model.model'
xgb_model.save_model(filename) #save

# %%
# 모델 불러오기
new_xgb_model = xgb.XGBRegressor() # 모델 초기화
new_xgb_model.load_model(filename) # 모델 불러오기

# %%
from sklearn.metrics import mean_squared_error

preds =new_xgb_model.predict(X_test)
mse = mean_squared_error(y_test, preds)
print("MSE: %f" % (mse))
# Out:
# MSE: 1.797273

# %%
y_test
# Out:
# array([[17.9, 17.3],
#        [19. , 17.7],
#        [17.6, 17.1],
#        ...,
#        [-2.4, -3.6],
#        [-1.8, -2.8],
#        [ 4.5,  3.2]])

# %%
preds
# Out:
# array([[18.65938  , 17.413435 ],
#        [18.639639 , 17.796257 ],
#        [18.359518 , 17.179134 ],
#        ...,
#        [-2.1175177, -3.2741113],
#        [-2.863707 , -3.3242216],
#        [ 3.2096543,  3.1309454]], dtype=float32)

# %%
import matplotlib.pyplot as plt

lst_pr = []
ta_pr = []
for i in range(len(preds)):
    lst_pr.append(preds[i][0])
    ta_pr.append(preds[i][1])
    
lst_re = []
ta_re = []
for i in range(len(y_test)):
    lst_re.append(y_test[i][0])
    ta_re.append(y_test[i][1])
    
def value_compare():
  plt.subplot(211)
  plt.plot(lst_pr[500:550], color = 'b', label = 'pred')
  plt.plot(lst_re[500:550], color = 'g', label = 'real')
  plt.ylabel('LST')
  plt.legend()

  plt.subplot(212)
  plt.plot(ta_pr[700:750], color = 'r', label = 'pred')
  plt.plot(ta_re[700:750], color = 'black', label = 'real')
  plt.ylabel('TA')
  plt.legend()
  plt.show()  

value_compare()

# %%
test_ = test.drop(['Band2','Band3','Band4','Band5','Band6','Band7','Band8','Band9','Band10','Band11','Band12',
            'Band13','Band14','Band15','Band16','30daysBand3','30daysBand13','GK2A-LST',
           'insitu-TED0.2','insitu-TED0.3','insitu-TED0.5','insitu-TED1.0','insitu-TED1.5','insitu-TED3.0',
           'insitu-TED5.0','insitu-PA','insitu-PS','YearMonthDayHourMinute',
           'STN','Lon','Lat'], axis=1)

pred =new_xgb_model.predict(test_)
pred
# Out:
# array([[21.443012, 20.830887],
#        [21.08698 , 20.719671],
#        [20.30491 , 19.146164],
#        ...,
#        [22.91291 , 20.188633],
#        [19.1995  , 17.62942 ],
#        [26.673687, 24.30179 ]], dtype=float32)

# %%
submission=pd.read_csv('./1-2_검증데이터셋.csv', encoding='utf-8')
submission
# Out:
#        YearMonthDayHourMinute  STN  isitu-LST  insitu-TA
# 0                202107010030   90        NaN        NaN
# 1                202107010030   93        NaN        NaN
# 2                202107010030   95        NaN        NaN
# 3                202107010030   98        NaN        NaN
# 4                202107010030   99        NaN        NaN
# ...                       ...  ...        ...        ...
# 54498            202108312330  973        NaN        NaN
# 54499            202108312330  974        NaN        NaN
# 54500            202108312330  977        NaN        NaN
# 54501            202108312330  978        NaN        NaN
# 54502            202108312330  980        NaN        NaN
#
# [54503 rows x 4 columns]

# %%
submission[['isitu-LST', 'insitu-TA']] = pred
submission
# Out:
#        YearMonthDayHourMinute  STN  isitu-LST  insitu-TA
# 0                202107010030   90  21.443012  20.830887
# 1                202107010030   93  21.086981  20.719671
# 2                202107010030   95  20.304911  19.146164
# 3                202107010030   98  20.688839  19.713287
# 4                202107010030   99  20.752316  20.130873
# ...                       ...  ...        ...        ...
# 54498            202108312330  973  25.232229  24.131443
# 54499            202108312330  974  23.407143  24.086641
# 54500            202108312330  977  22.912910  20.188633
# 54501            202108312330  978  19.199499  17.629419
# 54502            202108312330  980  26.673687  24.301790
#
# [54503 rows x 4 columns]

# %%
submission.to_csv("220224.csv", index = False)
